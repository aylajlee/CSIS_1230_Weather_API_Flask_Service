# %% [markdown]
# ## Flask Response Types
#
# ### Overview
# In Flask, view functions can return various types of responses beyond just strings and HTML.
#
# Understanding these different return types is crucial for building robust web applications.
#
# ### 1. String Responses
#
# **Basic Strings**

# %%
@app.route('/string')
def return_string():
    return "This is a plain text string"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2640/1238454350.py in <module>
# ----> 1 @app.route('/string')
#       2 def return_string():
#       3     return "This is a plain text string"
#
# NameError: name 'app' is not defined

# %% [markdown]
# **HTML Strings**

# %%
@app.route('/html-string')
def return_html_string():
    return '<h1>Hello</h1><p>This is HTML</p>'

# %% [markdown]
# ### 2. Template Responses
#
# **Using render_template()**

# %%
from flask import render_template

@app.route('/template')
def return_template():
    return render_template('index.html', title='Home Page')

# %% [markdown]
# **Template with Context**

# %%
@app.route('/user/<name>')
def user_profile(name):
    return render_template('profile.html', 
                         username=name, 
                         email=f"{name}@example.com")
    
from flask import Flask, render_template, jsonify, redirect, url_for, send_file, Response, abort, make_response
import json

app = Flask(__name__)

# 1. String response
@app.route('/')
def home():
    return "Welcome to the home page"
### http://localhost 이런 식으로 만들기

# %% [markdown]
# ### 3. JSON Responses
#
# **Using jsonify()**

# %%
from flask import jsonify

@app.route('/api/data')
def return_json():
    data = {
        'name': 'John Doe',
        'age': 30,
        'email': 'john@example.com'
    }
    return jsonify(data)
    # jsonify:
    # 1. converts Python dictionary → JSON
    # 2. Sets the correct HTTP headers i.e. Content-Type: application/json so that the client can parse it appropriately

# %% [markdown]
# **JSON with Status Code**

# %%
@app.route('/api/create', methods=['POST'])
def create_item():
    # Process data...
    return jsonify({'message': 'Item created', 'id': 123}), 201

# %% [markdown]
# ### 4. Redirect Responses
#
# **Using redirect()**

# %%
from flask import redirect, url_for

@app.route('/old-url')
def old_url():
    return redirect('/new-url')

@app.route('/go-home')
def go_home():
    return redirect(url_for('home'))  # Using endpoint name

# %% [markdown]
# **Redirect with Parameters**

# %%
@app.route('/login')
def login():
    # After successful login
    return redirect(url_for('dashboard', username='john'))

# %% [markdown]
# ### 5. File Responses
#
# **Using send_file()**

# %%
from flask import send_file

@app.route('/download')
def download_file():
    return send_file('path/to/file.pdf', 
                    as_attachment=True, 
                    download_name='document.pdf')

# %% [markdown]
# **Serving Static Files**

# %%
@app.route('/static-file')
def static_file():
    return send_file('static/images/photo.jpg')

# %% [markdown]
# ### 6. Custom Response Objects
#
# **Creating Response Objects**

# %%
from flask import Response

@app.route('/custom')
def custom_response():
    response = Response("Custom response", mimetype='text/plain')
    response.headers['X-Custom-Header'] = 'MyValue'
    response.headers['temperature'] = '15 F'
    return response

# %% [markdown]
# **Streaming Responses**

# %%
@app.route('/stream')
def stream_data():
    def generate():
        for i in range(5):
            yield f"Data chunk {i}\n"
    return Response(generate(), mimetype='text/plain')

# %% [markdown]
# ### 7. Error Responses
#
# **Using abort()**

# %%
from flask import abort

@app.route('/admin')
def admin_page():
    if not user_is_admin:
        abort(403)  # Forbidden
    return "Admin panel"

# %% [markdown]
# **Custom Error Pages**

# %%
@app.errorhandler(404)
def page_not_found(error):
    return render_template('404.html'), 404

@app.errorhandler(500)
def internal_error(error):
    return render_template('500.html'), 500

# %% [markdown]
# ### 8. Tuple Responses
#
# **Response with Status Code**

# %%
@app.route('/created')
def created_response():
    return "Resource created successfully", 201

@app.route('/accepted')
def accepted_response():
    return "Request accepted", 202

# %% [markdown]
# ## Class Exercise
#
# - Complete Example Demonstrating Multiple Return Types
#
# - Create a python file and run the code below:

# %%
from flask import Flask, render_template, jsonify, redirect, url_for, send_file, Response, abort, make_response
import json

app = Flask(__name__)

# 1. String response
@app.route('/')
def home():
    return "Welcome to the home page"

# 2. HTML String response
@app.route('/html_string')
def html_string():
    return '<h1>Hi this is my first app!</h1>'

# 3. HTML template response
@app.route('/dashboard')
def dashboard():
    return render_template('dashboard.html', user='John')

# 4. Passing python variables to your html page
@app.route('/cities')
def cities():
  cities = ["Chicago", "Austin", "New York"]
  return render_template('index.html', title="Weather Dashboard", cities=cities)


# 5. Redirect response
@app.route('/old-page')
def old_page():
    return redirect(url_for('dashboard'))

# 6. Return JSON API response
@app.route('/api/users')
def api_users():
    users = [{'id': 1, 'name': 'Alice'}, {'id': 2, 'name': 'Bob'}]
    return jsonify(users)

# 7. Tuple string response with status
@app.route('/create', methods=['POST'])
def create():
    return "Item created", 201

# 8. Tuple JSON response with status
@app.route('/api/create', methods=['POST'])
def create_item():
    # Process data...
    
    return jsonify({'message': 'Item created', 'id': 123}), 201

# 9. Passing parameters through URL routes to html
@app.route('/user/<name>')
def user_profile(name):
    return render_template('profile.html', 
                         username=name, 
                         email=f"{name}@example.com")

# 10. Custom response with headers
@app.route('/custom')
def custom_response():
    response = Response("Custom response", mimetype='text/plain')
    response.headers['X-Custom-Header'] = 'MyValue'
    response.headers['temperature'] = '15 F'
    response.headers['X-API-Version'] = '2.0'
    return response

# 11. File download
@app.route('/download-report')
def download_report():
    return send_file('reports/Resume_JuyeonLee.pdf', as_attachment=True)


# 12. 405 Errorhandler
@app.errorhandler(405)
def page_not_found(error):
    return render_template('405.html'), 405


if __name__ == '__main__':
    app.run(debug=True)
